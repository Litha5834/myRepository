# %%
import pandas as pd
import matplotlib.pylot as plt,numpy as np, random as rd, pandas as pd
# %matplotlib inline

data1= {'CHIPS' : ['Simba','Lays','Crack a Snack','Pringles'],
        'PRICE' : [9.00,9.00,1.50,18.00],
        'QUANTITY':[20,17,12,21],
        'COOLDRINKS':['Coke','Fanta','Mountain Dew','Pepsi'],
        'PRICE1':[10.00,10.00,9.00,12.00],
        'QUANTITY1':[24,20,12,17],
        'CHOCOLATES':['Cadbury','Tax','Bar One','Lindt'],
        'PRICE2':[12.00,9.00,12.00,30.00],
        'QUANTITY2':[13,17,11,21,],
        'PIES':['Pepper Steak','Chicken','Burger','Steak & Kidney'],
        'PRICE3':[15.00,15.00,15.00,15.00],
        'QUANTITY3':[20,27,30,21],
        'FRUIT':['Pear','Apple','Guava','Mango'],
        'PRICE4':[3.00,2.50,3.00,7.00],
        'QUANTITY4':[45,37,38,29],
        'CUPCAKES':['Vanilla','Chocolate','Red Velvet','Dark Forest'],
        'PRICE5':[8.00,8.00,8.00,8.00],
        'QUANTITY5':[24,30,27,21] }

data_list= [data1]
for i in data_list:
    df=pd.DataFrame(i)
df
# Out:
#            CHIPS  PRICE  QUANTITY    COOLDRINKS  PRICE1  QUANTITY1 CHOCOLATES  \
# 0          Simba    9.0        20          Coke    10.0         24    Cadbury
# 1           Lays    9.0        17         Fanta    10.0         20        Tax
# 2  Crack a Snack    1.5        12  Mountain Dew     9.0         12    Bar One
# 3       Pringles   18.0        21         Pepsi    12.0         17      Lindt
#
#    PRICE2  QUANTITY2            PIES  PRICE3  QUANTITY3  FRUIT  PRICE4  \
# 0    12.0         13    Pepper Steak    15.0         20   Pear     3.0
# 1     9.0         17         Chicken    15.0         27  Apple     2.5
# 2    12.0         11          Burger    15.0         30  Guava     3.0
# 3    30.0         21  Steak & Kidney    15.0         21  Mango     7.0
#
#    QUANTITY4     CUPCAKES  PRICE5  QUANTITY5
# 0         45      Vanilla     8.0         24
# 1         37    Chocolate     8.0         30
# 2         38   Red Velvet     8.0         27
# ...

# %%
df.to_csv("fileONE.csv",index=False,header=False)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="5834litha"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
    print(x)
# Out:
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
x = ["Simba","Lays","Crack n Snack","Pringles",'Coke','Fanta','Mountain Dew','Pepsi','Cadbury','Tax','Bar One','Lindt','Pepper Steak','Chicken','Burger','Steak & Kidney','Pear','Apple','Guava','Mango','Vanilla','Chocolate','Red Velvet','Dark Forest']
y = [9.00,9.00,1.50,18.00,10.00,10.00,9.00,12.00,12.00,9.00,12.00,30.00,15.00,15.00,15.00,15.00,3.00,2.50,3.00,7.00,8.00,8.00,8.00,8.00]

fig = plt.figure()
plt.plot(x,y,'g',label='linegraph',linewidth=5)
plt.title("Price range")
plt.xlabel('Item')
plt.ylabel('Price(R)')
plt.legend()
plt.xticks(rotation=90)

plt.grid(True,color='k')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x= ["Simba","Lays","Crack n Snack","Pringles",'Coke','Fanta','Mountain Dew','Pepsi','Cadbury','Tax','Bar One','Lindt','Pepper Steak','Chicken','Burger','Steak & Kidney','Pear','Apple','Guava','Mango','Vanilla','Chocolate','Red Velvet','Dark Forest']
y = [9.00,9.00,1.50,18.00,10.00,10.00,9.00,12.00,12.00,9.00,12.00,30.00,15.00,15.00,15.00,15.00,3.00,2.50,3.00,7.00,8.00,8.00,8.00,8.00]
plt.bar(x,y,)
plt.title("Prices Range")
plt.xlabel("Items Sold")
plt.ylabel("Price(R)")
plt.xticks(rotation=90)
plt.show()

# %%
#help(plt.plot)

# %%
x= ["Simba","Lays","Crack n Snack","Pringles",'Coke','Fanta','Mountain Dew','Pepsi','Cadbury','Tax','Bar One','Lindt','Pepper Steak','Chicken','Burger','Steak & Kidney','Pear','Apple','Guava','Mango','Vanilla','Chocolate','Red Velvet','Dark Forest']
y=[20,17,12,21,24,20,12,17,13,17,11,21,20,27,30,21,45,37,38,29,24,30,27,21]
plt.bar(x,y,)
plt.title("Purchased items")
plt.xlabel("Items Sold")
plt.ylabel("Amount sold")
plt.xticks(rotation=90)
plt.show()

# %%
x= ["Simba","Lays","Crack n Snack","Pringles",'Coke','Fanta','Mountain Dew','Pepsi','Cadbury','Tax','Bar One','Lindt','Pepper Steak','Chicken','Burger','Steak & Kidney','Pear','Apple','Guava','Mango','Vanilla','Chocolate','Red Velvet','Dark Forest']
y=[20,17,12,21,24,20,12,17,13,17,11,21,20,27,30,21,45,37,38,29,24,30,27,21]
plt.scatter(x,y)
plt.title("Purchased items")
plt.xlabel("Items")
plt.ylabel(" Amount Sold")
plt.xticks(rotation=90)
plt.show()
